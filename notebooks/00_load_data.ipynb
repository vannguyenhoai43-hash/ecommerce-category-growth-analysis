# %% [markdown]
# <a href="https://colab.research.google.com/github/vannguyenhoai43-hash/ecommerce-category-growth-analysis/blob/main/notebooks/00_load_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 00_load_data (Data đã được xử lý bằng SQL)
#
# Dữ liệu sử dụng trong project này đã được:
# - Làm sạch
# - Chuẩn hoá
# - Tổng hợp theo theo các tháng
#
# toàn bộ bằng SQL trước khi đưa vào Python.
#
# Notebook này chỉ thực hiện:
# - Load dữ liệu đầu vào
# - Kiểm tra cấu trúc dữ liệu
# - Chuẩn bị dataframe dùng cho các notebook phân tích

# %% [markdown]
# B1: Import Thư viện

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# B2: Load data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path_lv2   = "/content/drive/MyDrive/python/Quick_Report/Data_by_Month/Sep/data_by_level2.csv"
path_items = "/content/drive/MyDrive/python/Quick_Report/Data_by_Month/Sep/data_by_item.csv"

df_source_lv2   = pd.read_csv(path_lv2)
df_source_items = pd.read_csv(path_items)

# %% [markdown]
# Lọc data theo tháng hiện tại

# %%
df_cur_items = df_source_items[df_source_items['year_month'] == '2024-09']

# %%
df_cur_lv2 = df_source_lv2[df_source_lv2['year_month'] == '2024-09']

# %% [markdown]
# Kiểm tra nhanh dữ liệu

# %%
df_cur_items.head()
# Out:
#    year_month   shop_id      item_id  \
# 4     2024-09  90668226  10000500212
# 12    2024-09  17469488  10001604137
# 15    2024-09  17469488  10001605847
# 18    2024-09  17469488  10001607397
# 22    2024-09   3075268  10002273942
#
#                                             item_name  \
# 4                       Kính lúp đa năng - Có tay kẹp
# 12  Gương Cầu Chiếu Hậu Xe Máy Chân 10ly Hàng Đẹp ...
# 15  Mui Rùa Lót Đuôi Trong xe DREAM TD Cao Cấp [D...
# 18  Cặp Inox Bảo Vệ Lốc Máy TD Lắp Dream Việt Hàng...
# 22                Miếng chống trượt trên taplo xe hơi
#
#          level1_kpi_category        level2_kpi_category     ADO_M   AdGMV_M  \
# 4   Tools & Home Improvement  Large tools and equipment  0.051111  0.394361
# 12                Automotive      Motorbike Accessories  1.533333  2.935698
# 15                Automotive        Auto Parts & Spares  0.051111  0.111004
# 18                Automotive      Motorbike Spare Parts  0.083148  0.630599
# ...

# %%
df_cur_items.shape
# Out:
# (96631, 10)

# %%
df_cur_items.isna().sum()
# Out:
# year_month                 0
# shop_id                    0
# item_id                    0
# item_name                  0
# level1_kpi_category        0
# level2_kpi_category        0
# ADO_M                      0
# AdGMV_M                    0
# ADO_M_1                28048
# AdGMV_M_1              28048
# dtype: int64
